# %%
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Activation

# load dataset
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

dataset = pd.read_csv("sample_data/diabetes.csv", header=None).values

X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8], test_size=0.25, random_state=87)
np.random.seed(155)


my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer


my_first_nn.compile(loss='binary_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy'])


my_first_nn_fitted = my_first_nn.fit(X_train,
                                     Y_train,
                                     epochs=100,
                                     initial_epoch=0,
                                     validation_data=(X_test, Y_test))

print(my_first_nn.evaluate(X_test, Y_test))

# Plot the loss and accuracy for both training and validation data
plt.plot(my_first_nn_fitted.history['accuracy'])
plt.plot(my_first_nn_fitted.history['val_accuracy'])
plt.title('Model Initial Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3141 - loss: 8.9567 - val_accuracy: 0.4427 - val_loss: 3.1334
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5237 - loss: 2.6806 - val_accuracy: 0.5312 - val_loss: 2.4762
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5934 - loss: 2.0932 - val_accuracy: 0.5521 - val_loss: 2.1237
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5536 - loss: 2.0133 - val_accuracy: 0.5365 - val_loss: 1.8311
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5740 - loss: 1.5622 - val_accuracy: 0.5573 - val_loss: 1.6196
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.model_selection import train_test_split


diabetes_dataset = pd.read_csv("sample_data/diabetes.csv", header=None).values


X_train, X_test, Y_train, Y_test = train_test_split(diabetes_dataset[:,0:8], diabetes_dataset[:,8], test_size=0.25, random_state=87)
np.random.seed(155)


diabetes_dnn = Sequential() # create model
diabetes_dnn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer 1
diabetes_dnn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer 2
diabetes_dnn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer 3
diabetes_dnn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer 4
diabetes_dnn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer 5
diabetes_dnn.add(Dense(1, activation='sigmoid')) # output layer


diabetes_dnn.compile(loss='binary_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy'])


diabetes_dnn_fitted = diabetes_dnn.fit(X_train,
                                     Y_train,
                                     epochs=100,
                                     initial_epoch=0,
                                     validation_data=(X_test, Y_test))

print(diabetes_dnn.evaluate(X_test, Y_test))


plt.plot(diabetes_dnn_fitted.history['accuracy'])
plt.plot(diabetes_dnn_fitted.history['val_accuracy'])
plt.title('Model Accuracy after adding 4 Dense layers')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.5235 - loss: 1.0141 - val_accuracy: 0.6198 - val_loss: 0.6821
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6844 - loss: 0.6498 - val_accuracy: 0.6771 - val_loss: 0.6458
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6732 - loss: 0.6400 - val_accuracy: 0.6302 - val_loss: 0.6832
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7103 - loss: 0.5907 - val_accuracy: 0.6510 - val_loss: 0.6402
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6854 - loss: 0.5938 - val_accuracy: 0.6198 - val_loss: 0.6454
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.model_selection import train_test_split


cancer_dataset = pd.read_csv("sample_data/breastcancer.csv")


X = cancer_dataset.drop("diagnosis", axis=1)
Y = pd.DataFrame()
Y.loc[:, 'diagnosis'] = cancer_dataset.loc[:, 'diagnosis']


Y['diagnosis'].replace('M', 1, inplace=True)
Y['diagnosis'].replace('B', 0, inplace=True)


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=87)
np.random.seed(155)


cancer_dnn = Sequential() # create model
cancer_dnn.add(Dense(20, activation='relu')) # hidden layer 1
cancer_dnn.add(Dense(20, activation='relu')) # hidden layer 2
cancer_dnn.add(Dense(20, activation='relu')) # hidden layer 3
cancer_dnn.add(Dense(20, activation='relu')) # hidden layer 4
cancer_dnn.add(Dense(20, activation='relu')) # hidden layer 5
cancer_dnn.add(Dense(1, activation='sigmoid')) # output layer


cancer_dnn.compile(loss='binary_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy'])


cancer_dnn_fitted = cancer_dnn.fit(X_train,
                           Y_train,
                           epochs=100,
                           initial_epoch=0,
                           validation_data=(X_test, Y_test))

print(cancer_dnn.evaluate(X_test, Y_test))

# Plot the loss and accuracy for both training and validation data
plt.plot(cancer_dnn_fitted.history['accuracy'])
plt.plot(cancer_dnn_fitted.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6321 - loss: nan - val_accuracy: 0.6503 - val_loss: nan
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6100 - loss: nan - val_accuracy: 0.6503 - val_loss: nan
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6329 - loss: nan - val_accuracy: 0.6503 - val_loss: nan
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6341 - loss: nan - val_accuracy: 0.6503 - val_loss: nan
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6121 - loss: nan - val_accuracy: 0.6503 - val_loss: nan
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5902 - loss: nan - val_accuracy: 0.6503 - val_loss: nan
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6101 - loss: nan - val_accuracy: 0.6503 - val_loss: nan
# Epoch 8/100
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Activation
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


cancer_norm_dataset = pd.read_csv("sample_data/breastcancer.csv")


X = cancer_norm_dataset.drop("diagnosis", axis=1)
Y = pd.DataFrame()
Y.loc[:, 'diagnosis'] = cancer_norm_dataset.loc[:, 'diagnosis']


Y['diagnosis'].replace('M', 1, inplace=True)
Y['diagnosis'].replace('B', 0, inplace=True)


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=87)
np.random.seed(155)


sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)


cancer_norm_dnn = Sequential() # create model
cancer_norm_dnn.add(Dense(20, activation='relu')) # hidden layer 1
cancer_norm_dnn.add(Dense(20, activation='relu')) # hidden layer 2
cancer_norm_dnn.add(Dense(20, activation='relu')) # hidden layer 3
cancer_norm_dnn.add(Dense(20, activation='relu')) # hidden layer 4
cancer_norm_dnn.add(Dense(20, activation='relu')) # hidden layer 5
cancer_norm_dnn.add(Dense(1, activation='sigmoid')) # output layer


cancer_norm_dnn.compile(loss='categorical_crossentropy',
                        optimizer='adam',
                        metrics=['accuracy'])


cancer_norm_dnn_fitted = cancer_norm_dnn.fit(X_train,Y_train,
                                             epochs=100,
                                             initial_epoch=0,
                                             validation_data=(X_test, Y_test))


# Plot the loss and accuracy for both training and validation data
plt.plot(cancer_norm_dnn_fitted.history['accuracy'])
plt.plot(cancer_norm_dnn_fitted.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# /usr/local/lib/python3.10/dist-packages/keras/src/losses/losses.py:27: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.5312 - loss: nan
# ...

# %%
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()


#convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')

#scale data
train_data /=255.0
test_data /=255.0

#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

#creating network
mnist_dnn = Sequential()
mnist_dnn.add(Dense(512, activation='relu', input_shape=(dimData,)))
mnist_dnn.add(Dense(512, activation='relu'))
mnist_dnn.add(Dense(10, activation='softmax'))

mnist_dnn.compile(optimizer='rmsprop',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])


mnist_dnn_history = mnist_dnn.fit(train_data,
                                  train_labels_one_hot,
                                  batch_size=256,
                                  epochs=10,
                                  verbose=1,
                                  validation_data=(test_data, test_labels_one_hot))

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(mnist_dnn_history.history['accuracy'])
plt.plot(mnist_dnn_history.history['val_accuracy'])
plt.title('Training and Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')


plt.subplot(1, 2, 2)
plt.plot(mnist_dnn_history.history['loss'])
plt.plot(mnist_dnn_history.history['val_loss'])
plt.title('Training and Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8365 - loss: 0.5261 - val_accuracy: 0.9616 - val_loss: 0.1198
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9651 - loss: 0.1111 - val_accuracy: 0.9747 - val_loss: 0.0851
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 26ms/step - accuracy: 0.9793 - loss: 0.0646 - val_accuracy: 0.9701 - val_loss: 0.0913
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9860 - loss: 0.0440 - val_accuracy: 0.9794 - val_loss: 0.0703
# Epoch 5/10
# ...

# %%
idx = np.random.randint(test_data.shape[0])
image = test_data[idx].reshape(28, 28)

# plot the selected image
plt.figure()
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title('Selected Image')

# do inferencing to check the model prediction on the selected image
prediction = mnist_dnn.predict(image.reshape(1, 784))
prediction = np.argmax(prediction)

# print the predicted label
print('Predicted label:', prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Predicted label: 4

# %%
import matplotlib.pyplot as plt
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()


#convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')

#scale data
train_data /=255.0
test_data /=255.0

#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)


#creating network
mnist_more_dnn = Sequential()
mnist_more_dnn.add(Dense(512, activation='relu', input_shape=(dimData,)))
mnist_more_dnn.add(Dense(512, activation='relu'))
mnist_more_dnn.add(Dense(128, activation='tanh'))
mnist_more_dnn.add(Dense(64, activation='tanh'))
mnist_more_dnn.add(Dense(10, activation='sigmoid'))

mnist_more_dnn.compile(optimizer='rmsprop',
                       loss='categorical_crossentropy',
                       metrics=['accuracy'])

mnist_more_dnn_history = mnist_more_dnn.fit(train_data,
                             train_labels_one_hot,
                             batch_size=256,
                             epochs=10,
                             verbose=1,
                             validation_data=(test_data, test_labels_one_hot))


plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(mnist_more_dnn_history.history['accuracy'])
plt.plot(mnist_more_dnn_history.history['val_accuracy'])
plt.title('Training and Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')


plt.subplot(1, 2, 2)
plt.plot(mnist_more_dnn_history.history['loss'])
plt.plot(mnist_more_dnn_history.history['val_loss'])
plt.title('Training and Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 12s 45ms/step - accuracy: 0.8167 - loss: 0.5912 - val_accuracy: 0.9558 - val_loss: 0.1453
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.9664 - loss: 0.1073 - val_accuracy: 0.9743 - val_loss: 0.0816
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 31ms/step - accuracy: 0.9804 - loss: 0.0638 - val_accuracy: 0.9695 - val_loss: 0.0998
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.9870 - loss: 0.0401 - val_accuracy: 0.9727 - val_loss: 0.0960
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 36ms/step - accuracy: 0.9908 - loss: 0.0298 - val_accuracy: 0.9713 - val_loss: 0.0998
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - accuracy: 0.9933 - loss: 0.0223 - val_accuracy: 0.9805 - val_loss: 0.0662
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.9949 - loss: 0.0175 - val_accuracy: 0.9822 - val_loss: 0.0643
# Epoch 8/10
# ...

# %%
import matplotlib.pyplot as plt
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()


#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')

'''#scale data
train_data /=255.0
test_data /=255.0'''

#change the labels from integer to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

#creating network
mnist_noscale_dnn = Sequential()
mnist_noscale_dnn.add(Dense(512, activation='relu', input_shape=(dimData,)))
mnist_noscale_dnn.add(Dense(512, activation='relu'))
mnist_noscale_dnn.add(Dense(128, activation='tanh'))
mnist_noscale_dnn.add(Dense(64, activation='tanh'))
mnist_noscale_dnn.add(Dense(10, activation='sigmoid'))

mnist_noscale_dnn.compile(optimizer='rmsprop',
                          loss='categorical_crossentropy',
                          metrics=['accuracy'])

mnist_noscale_dnn_history = mnist_noscale_dnn.fit(train_data,
                                                  train_labels_one_hot,
                                                  batch_size=256,
                                                  epochs=10,
                                                  verbose=1,
                                                  validation_data=(test_data, test_labels_one_hot))

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(mnist_noscale_dnn_history.history['accuracy'])
plt.plot(mnist_noscale_dnn_history.history['val_accuracy'])
plt.title('Training and Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')


plt.subplot(1, 2, 2)
plt.plot(mnist_noscale_dnn_history.history['loss'])
plt.plot(mnist_noscale_dnn_history.history['val_loss'])
plt.title('Training and Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - accuracy: 0.6156 - loss: 1.2069 - val_accuracy: 0.8731 - val_loss: 0.4238
# Epoch 2/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 0.8820 - loss: 0.3870 - val_accuracy: 0.8989 - val_loss: 0.3358
# Epoch 3/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - accuracy: 0.9056 - loss: 0.3147 - val_accuracy: 0.9237 - val_loss: 0.2651
# Epoch 4/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9140 - loss: 0.2882 - val_accuracy: 0.9189 - val_loss: 0.2745
# Epoch 5/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - accuracy: 0.9203 - loss: 0.2698 - val_accuracy: 0.9261 - val_loss: 0.2540
# Epoch 6/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 38ms/step - accuracy: 0.9230 - loss: 0.2505 - val_accuracy: 0.9264 - val_loss: 0.2474
# Epoch 7/10
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.9298 - loss: 0.2324 - val_accuracy: 0.9263 - val_loss: 0.2528
# Epoch 8/10
# ...
